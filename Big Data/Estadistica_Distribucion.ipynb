# %% [markdown]
# #**ESTADÍSTICA DESCRIPTIVA CON PYTHON**
# #**UNIVERSIDAD SANTIAGO DE CALI**
# #**FACULTAD DE INGENIERÍA**
# #**BIG DATA**
#
#
# ---
#
#
# *Freddy Alejandro Florez Bohorquez*
#
# *Manuel Osorio Escarpeta*
#
# *Orlando Correa Martinez*
#
#
# ---
#
#
# Referencias:
#
# **https://relopezbriega.github.io/blog/2015/06/27/probabilidad-y-estadistica-con-python/#:~:text=La%20estad%C3%ADstica%20descriptiva%3A%20La%20cual,que%20describen%20el%20conjunto%20estudiado.**
#
#
#
#
# **https://www.kaggle.com/code/pmarcelino/comprehensive-data-exploration-with-python/notebook**
#
#
# **https://seaborn.pydata.org/generated/seaborn.distplot.html**

# %% [markdown]
# Los principales módulos que Python nos ofrece para trabajar con probabilidad y estadística, son:
#
# **numpy:** El popular paquete matemático de Python, se utiliza tanto que mucha gente ya lo considera parte integral del lenguaje. Nos proporciona algunas funciones estadísticas que podemos aplicar fácilmente sobre los arrays de Numpy.
#
# **scipy.stats:** Este submodulo del paquete científico Scipy es el complemento perfecto para Numpy, las funciones estadísticas que no encontremos en uno, las podemos encontrar en el otro.
#
# **matplotlib:** Es la librería más popular en Python para visualizaciones y gráficos. Ella nos va a permitir realizar los gráficos de las distintas distribuciones de datos.
#
# **seaborn:** Esta librería es un complemento ideal de matplotlib para realizar gráficos estadísticos.
#
# **pandas:** Esta es la librería más popular para análisis de datos y financieros. Posee algunas funciones muy útiles para realizar estadística descriptiva sobre nuestros datos y nos facilita sobremanera el trabajar con series de tiempo.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from scipy.stats import norm
from scipy import stats
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# Definir la ubicacion del archivo CSV con la base de datos

# %%
url = "/content/drive/MyDrive/Big Data/train.csv"
df_train = pd.read_csv(url)

# %% [markdown]
# Impresion de los primeros n registros

# %%
df_train.head(100)
# Out:
#      Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0     1          60       RL         65.0     8450   Pave   NaN      Reg
# 1     2          20       RL         80.0     9600   Pave   NaN      Reg
# 2     3          60       RL         68.0    11250   Pave   NaN      IR1
# 3     4          70       RL         60.0     9550   Pave   NaN      IR1
# 4     5          60       RL         84.0    14260   Pave   NaN      IR1
# ..  ...         ...      ...          ...      ...    ...   ...      ...
# 95   96          60       RL          NaN     9765   Pave   NaN      IR2
# 96   97          20       RL         78.0    10264   Pave   NaN      IR1
# 97   98          20       RL         73.0    10921   Pave   NaN      Reg
# 98   99          30       RL         85.0    10625   Pave   NaN      Reg
# 99  100          20       RL         77.0     9320   Pave   NaN      IR1
#
#    LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal  \
# ...

# %% [markdown]
# Impresión del tamaño de la base de datos

# %%
df_train.shape
# Out:
# (1460, 81)

# %% [markdown]
# Estadística descriptiva de un campo seleccionados

# %%
df_train['SalePrice'].describe()
# Out:
# count      1460.000000
# mean     180921.195890
# std       79442.502883
# min       34900.000000
# 25%      129975.000000
# 50%      163000.000000
# 75%      214000.000000
# max      755000.000000
# Name: SalePrice, dtype: float64

# %% [markdown]
# Calcular la Media

# %%
df_train['SalePrice'].mean()
# Out:
# 180921.19589041095

# %% [markdown]
# Calcular la Mediana

# %%
df_train['SalePrice'].median()
# Out:
# 163000.0

# %% [markdown]
# Calcular la Moda

# %%
df_train['SalePrice'].mode()
# Out:
# 0    140000
# dtype: int64

# %% [markdown]
# Calcula la desviación estándar poblacional

# %%
df_train['SalePrice'].std(ddof=0)
# Out:
# 79415.29188606751

# %% [markdown]
# Calcula la varianza poblacional

# %%
df_train['SalePrice'].var(ddof=0)
# Out:
# 6306788585.349301

# %% [markdown]
# Calcula el Rango a partir de la resta del valor máximo y mínimo de una columna

# %%
df_train['SalePrice'].max()-df_train['SalePrice'].min()
# Out:
# 720100

# %% [markdown]
# Calcula el coeficiente de variación de Pearson

# %%
df_train['SalePrice'].std(ddof=0)/df_train['SalePrice'].mean()
# Out:
# 0.4389496293965003

# %% [markdown]
# Impresión de un gráfico de distribución de frecuencias relativas

# %%
sns.distplot(df_train['SalePrice']);

# %% [markdown]
# Impresión de un gráfico de distribución de frecuencias absolutas como histograma

# %%
hist, bin_edges = np.histogram(df_train['SalePrice'], 11)
plt.hist(df_train['SalePrice'], bins=bin_edges)
plt.show()

# %% [markdown]
# Coeficiente de asimetría

# %%
df_train['SalePrice'].skew()
# Out:
# 1.8828757597682129

# %%
Curtosis

# %%
df_train['SalePrice'].kurt()
# Out:
# 6.536281860064529

# %% [markdown]
# Impresión de un gráfico de dispersión

# %%
data = pd.concat([df_train['SalePrice'], df_train['GrLivArea']], axis=1)
data.plot.scatter(x='GrLivArea', y='SalePrice', xlim=(0,6000), ylim=(0,800000));

# %%
data
# Out:
#       SalePrice  GrLivArea
# 0        208500       1710
# 1        181500       1262
# 2        223500       1786
# 3        140000       1717
# 4        250000       2198
# ...         ...        ...
# 1455     175000       1647
# 1456     210000       2073
# 1457     266500       2340
# 1458     142125       1078
# 1459     147500       1256
#
# [1460 rows x 2 columns]

# %% [markdown]
# Guardar tablas en formato Excel

# %%
data.to_excel("/content/drive/MyDrive/Big Data/Tabla_Dispersion.xlsx")

# %%
var = 'TotalBsmtSF'
data = pd.concat([df_train['SalePrice'], df_train[var]], axis=1)
data.plot.scatter(x=var, y='SalePrice', ylim=(0,800000));

# %% [markdown]
# Impresión de un gráfico de distribución de frecuencias con campana de Gauss y un gráfico de probabilidad con curva de regresión lineal

# %%
f, ax = plt.subplots(figsize=(9,7))
sns.distplot(df_train['SalePrice'], fit=norm);
fig = plt.figure()

f, ax = plt.subplots(figsize=(8.5,7))
res = stats.probplot(df_train['SalePrice'], plot=plt);

# %%
f, ax = plt.subplots(figsize=(9,7))
df_train['SalePrice'] = np.log(df_train['SalePrice'])
sns.distplot(df_train['SalePrice'], fit=norm);
fig = plt.figure()
f, ax = plt.subplots(figsize=(9,7))
res = stats.probplot(df_train['SalePrice'], plot=plt)
