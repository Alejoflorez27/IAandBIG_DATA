# %%
class Singleton_Class:
    __instance=None
    
    @staticmethod
    def getInstance():
        if Singleton_Class.__instance==None:
            Singleton_Class()
            return Singleton_Class.__instance
    def __init__(self):
        if Singleton_Class.__instance!=None:
            raise Exception("No pude crear otra instancia de la clase")
            #return Sigleton.__instance
        else:
            Singleton_Class.__instance=self


#metodos propios de la clase

    @classmethod
    def metodo1(self):
        pass

    def metodo2(self):
        pass

singleton1= Singleton_Class()
print(Singleton_Class)

#singleton2= Singleton_Class()
print(Singleton_Class)

#print(singleton1 is singleton2)
# Out:
# <class '__main__.Singleton_Class'>
# <class '__main__.Singleton_Class'>
