# %% [markdown]
# **Importar las librerias**

# %%
import tensorflow as tf
import matplotlib.pyplot as plt

# %% [markdown]
#  **Preparacion del Dataset**

# %%
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.fashion_mnist.load_data()
#Escalamiento de dataset
x_train, x_test = x_train /255.0, x_test / 255.0

# %% [markdown]
# **Tamaño del dataset tanto de entrenamiento como para pruebas**

# %%
x_train.shape, y_train.shape, x_test.shape, y_test.shape,
# Out:
# ((60000, 28, 28), (60000,), (10000, 28, 28), (10000,))

# %% [markdown]
# Manejo de graficas con matplolit

# %%
class_names = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat',
               'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']

plt.figure(figsize=(10,10))


#plt.title("Freddy Florez")
for i in range(25):
    #plt.title("Freddy Florez")
    plt.subplot(5,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(x_train[i], cmap=plt.cm.binary)
    plt.xlabel(class_names[y_train[i]])
#plt.title("Freddy Florez", position=(-1,3.5),
#          fontdict={'family': 'serif', 
#                   'color' : 'darkblue',
#                   'weight': 'bold',
#                   'size': 18})
#plt.title("Freddy Florez")
plt.show()

# %% [markdown]
# **Creacion del modelo de la red neuronal**

# %%
model = tf.keras.models.Sequential(
  [
    tf.keras.layers.Flatten(input_shape=(28, 28)),
    #Nodos de procesamiento
    tf.keras.layers.Dense(128, activation="relu"),
    #(10 nodos-10prendas)
    tf.keras.layers.Dense(10),
  ]
)

# %% [markdown]
# **Presente arquitectura del modelado**
# ver imagen de arquitectura

# %%
tf.keras.utils.plot_model(
  model,
  "/tmp/model.png",
  show_shapes=True,
)

# %%
predictions = model(x_train[:1]).numpy()
predictions
# Out:
# array([[-0.24863413,  0.55830365, -0.4473462 ,  0.5045733 ,  0.00809733,
#         -0.6929417 , -0.4867712 ,  0.1694796 , -1.076896  ,  0.7389501 ]],
#       dtype=float32)

# %%
# softmax = tf.exp(logits) / tf.reduce.sum(tf.exp(logits, axis)
tf.nn.softmax(predictions).numpy()
# Out:
# array([[0.07381532, 0.16542271, 0.06051276, 0.15676904, 0.09542091,
#         0.04733541, 0.05817346, 0.11213236, 0.03224311, 0.198175  ]],
#       dtype=float32)

# %%
(train_image, train_table), (test_image, test_table) = tf.keras.datasets.fashion_mnist.load_data()

plt.imshow(train_image[1])
plt.show
# Out:
# <function matplotlib.pyplot.show>
