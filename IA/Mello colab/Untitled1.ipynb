# %%
import numpy as np
import pandas as pd
import cv2 as cv 
from google.colab.patches import cv2_imshow # for image display
from skimage import io
from PIL import Image 
import matplotlib.pylab as plt

# %%
urls = ["/content/drive/MyDrive/GoogleColab/aleofb10.jpg"]

# %% [markdown]
# # Sección nueva

# %%
imageDw = io.imread("/content/drive/MyDrive/GoogleColab/aleofb10.jpg")
imageDw_2 = cv.cvtColor(imageDw, cv.COLOR_BGR2GRAY)
cv.imwrite("/content/drive/MyDrive/GoogleColab/test.jpg",imageDw_2)
# Out:
# True

# %%
# !wget --no-check-certificate \
    https://raw.githubusercontent.com/computationalcore/introduction-to-opencv/master/assets/haarcascade_frontalface_default.xml \
    -O haarcascade_frontalface_default.xml
# Out:
# --2021-09-25 04:12:38--  https://raw.githubusercontent.com/computationalcore/introduction-to-opencv/master/assets/haarcascade_frontalface_default.xml
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 930127 (908K) [text/plain]
# Saving to: ‘haarcascade_frontalface_default.xml’
#
# haarcascade_frontal 100%[===================>] 908.33K  --.-KB/s    in 0.02s
#
# 2021-09-25 04:12:38 (42.0 MB/s) - ‘haarcascade_frontalface_default.xml’ saved [930127/930127]

# %%
image_face = io.imread("/content/drive/MyDrive/GoogleColab/aleofb10.jpg") 
face_cascade = cv.CascadeClassifier('haarcascade_frontalface_default.xml')
face_cascade = cv.CascadeClassifier('haarcascade_smile.xml')

# %%
# !wget --no-check-certificate \
    https://raw.githubusercontent.com/computationalcore/introduction-to-opencv/master/assets/haarcascade_smile.xml \
    -O haarcascade_smile.xml
# Out:
# --2021-09-25 04:12:38--  https://raw.githubusercontent.com/computationalcore/introduction-to-opencv/master/assets/haarcascade_smile.xml
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 188506 (184K) [text/plain]
# Saving to: ‘haarcascade_smile.xml’
#
# haarcascade_smile.x 100%[===================>] 184.09K  --.-KB/s    in 0.009s
#
# 2021-09-25 04:12:38 (19.5 MB/s) - ‘haarcascade_smile.xml’ saved [188506/188506]

# %%
faces = face_cascade.detectMultiScale(image_face, 1.1 , 5)
smiles = face_cascade.detectMultiScale(image_face, 1.3 , 20 )
contadorface=0
contadorsmile=0
for (x,y,w,h) in faces:
     cv.rectangle(image_face,(x,y),(x+w,y+h),(255,0,0),2)
     contadorface+=1 
     for (x,y,w,h) in smiles:
       cv.rectangle(image_face, (x,y),(x+w,y+h),(0,255,0),2)
       contadorsmile+=1    
print("la cantidad de caras es:"+str(contadorface),"\nla cantidad de smiles es:"+str(contadorsmile))

cv.imwrite("/content/drive/MyDrive/GoogleColab/test1.jpg",image_face)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-7-e637a41b64ed> in <module>()
# ----> 1 faces = face_cascade.detectMultiScale(image_face, 1.1 , 5)
#       2 smiles = face_cascade.detectMultiScale(image_face, 1.3 , 20 )
#       3 contadorface=0
#       4 contadorsmile=0
#       5 for (x,y,w,h) in faces:
#
# error: OpenCV(4.1.2) /io/opencv/modules/objdetect/src/cascadedetect.cpp:1689: error: (-215:Assertion failed) !empty() in function 'detectMultiScale'

# %%
plt.imshow(image_face)
