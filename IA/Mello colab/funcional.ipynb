# %%
# -*- coding: utf-8 -*-
"""
Created on Wed May 18 19:57:31 2022

@author: estudiante
"""

#funcion iterativa

def factorial_iter(n):
    fact = 1
    for i in range(1, n + 1):
      fact = fact * i
    return fact


#funcion recursiva
def factorial_rec(n):
    if n == 0:
        return 1

    else:
        return n*factorial_rec(n-1)
    
#una funcion que recibe por parametro otra funcion
def usar_funcion(f, n):
    print(f"El factorial de n es: {f(n)}")
    #return f(n)

cual_funcion = factorial_iter

usar_funcion(factorial_iter, 5)

print(f"El factorial de n es: {cual_funcion(6)}")

#una funcion que recibe por parametro otra funcion
#composicion de funciones
def factorial_mas_eficiente1(n):
    return factorial_iter(n)
"""
#composicion de funciones (version 2)
def function_selector(n):
    def function_a(x,y):
        pass
    
    def function_b(x,y):
        pass
    
    def function_c(x,y):
        pass
    
    return function_a
"""

#devuelve el nombre de la funcion
def factorial_mas_eficiente2():
    return factorial_iter

factorial = factorial_mas_eficiente2()

#print(factorial_mas_eficiente1(4))
#print(factorial(4))

print(f"La funcion es:{factorial}")
print(factorial_mas_eficiente2()(4))

#Ejemplo de composicion de funciones:

#funcion de ordenamiento (sin funcion callback):
    
nombres = ["Diego", "Juan", "Pedro", "Camila", "Xiomara"]
#ordena de forma
#print(sorted(nombres))
#la funcion len se pas como Callback
def len_reverse(s):
    return -len(s)
print(sorted(nombres, key=len, reverse = True))

#print(sorted(nombres, key=len_reverse))

#funcion lambda (funcion anónimas):
print((lambda x,y: x+y)(4,5))

def len_reverse(s):
    return -len(s)


#composicion de funciones (opcion2)
def function_selector(n):
    def function_a(x,y):
        return x+y
    
    def function_b(x,y):
        return x*y
    
    def function_c(x,y):
        return x-y
    
    if n==1:
        return function_a
    elif n==2:
        return function_b
    else:
      return function_c

#En esta parte se le dice que operacion del selector se quiere realizar y una ves eso le mandamos los argumentos a la funcion selector que son (x,y)   
print(function_selector(1)(4,5))
print(function_selector(2)(4,5)) 
print(function_selector(3)(4,5)) 
          
#devuelve el nombre de la funcion

def factorial_ams_eficiente():
    return factorial_iter
# Out:
# El factorial de n es: 120
# El factorial de n es: 720
# La funcion es:<function factorial_iter at 0x7f3a0d4daef0>
# 24
# ['Xiomara', 'Camila', 'Diego', 'Pedro', 'Juan']
# 9
# 9
# 20
# -1
