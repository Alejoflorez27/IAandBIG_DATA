# %%
"""
#Clase Estudiante
class Estudiante:

  #Atributos de clase:
  campus = "Pampalinda"
  cursos = []

  #Metodo constructor
  def __init__(self, nombre, telefono):
    #atributos de instancia: son inicializados al crear una instacia de la clase (objeto)
    self.nombre = nombre
    self.telefono = telefono

  #Método matricular
  def matricular(self, nuevoCurso):
    self.cursos.append(nuevoCurso)
    print(f"nuevo curso agregando al estudiante: {self.nombre}")

  def imprimirCursosMatriculados(self):
    print(f"Cursos matriculados de estudiante: {self.nombre}")
    for c in self.cursos:
      print(f"\n{c}")


#objetos de la clase Estudiante
estudiante1 = Estudiante("Diego", "777")
estudiante1.matricular("Inteligencia Artificial")
estudiante3 = estudiante1

estudiante1.matricular("Estadistica")
estudiante3.imprimirCursosMatriculados()

"""
#estudiante2 = Estudiante("santi", "27")
#estudiante2.matricular("Bioquimica")
#estudiante2.matricular("Fisica")
#estudiante2.imprimirCursosMatriculados()
"""
#print(estudiante1)
#print(estudiante2)

#print(estudiante1 is estudiante2)
print(estudiante3 is estudiante1)
"""
# Out:
# '\n#print(estudiante1)\n#print(estudiante2)\n\n#print(estudiante1 is estudiante2)\nprint(estudiante3 is estudiante1)\n'

# %%
from turtle import pd
class Persona:
    def __init__(self,pDocumento,pNombre,pTelefono):
        self.documento=pDocumento
        self.nombre=pNombre
        self.telefono=pTelefono
#Clase Estudiante
class Estudiante(Persona):
    def __init__(self,pDocumento,pNombre,pTelefono,pCampus,pCursoElectivo):
        self.documento=pDocumento
        self.nombre=pNombre
        self.telefono=pTelefono
        self.campus=pCampus
        self.cursos=[]
        self.cursoElectivo = pCursoElectivo
        #self.cursoElectivo = Curso() #Define al asocioacion de composición

    def matricularCursos(self,nuevoCurso):
        self.cursos.append(nuevoCurso)

    def matricularCursoElectivo(self,pNuevoCursoElectivo):
        self.cursoElectivo=pNuevoCursoElectivo
    
    def imprimirCursosMatriculados(self):
        print(f"Cursos matriculados por {self.nombre}:")
        print(f"\nCurso electivo: {self.cursoElectivo.nombre}")
        print(F"Otros cursos matriculados: ")
        for c in self.cursos:
            print(f"{c}")

#Clase Profesor
class Profesor(Persona):
    def __init__(self,pDocumento,pNombre,pTelefono,pCampus,pCursoElectivo):
        self.documento=pDocumento
        self.nombre=pNombre
        self.telefono=pTelefono

#objetos de la clase Estudiante
#estudiante1 = Estudiante("Diego", "777","Diego")
#estudiante2 = Estudiante("Palmira", "888","Diana")

class Curso:

  def __init__(self, pCodigo="", pNombre="", pCreditos="", pNotaFinal=0):
      self.codigo = pCodigo
      self.nombre = pNombre
      self.creditos = pCreditos
      self.notaFinal = pNotaFinal
    

  def cambiarNotaFinal(self, pNuevaNota):
      self.notaFinal = pNuevaNota

documento = input("Digite el documento del primer estudiante: ")
nombre_estudiante = input("Digite el nombre del primer estudiante: ")
telefono_estudiante = input("Digite el telefono del primer estudiante: ")
cursoElectivo1 = Curso("EM301", "Disin Thiking", "3")

estudiante1 = Estudiante(documento,nombre_estudiante,telefono_estudiante,"USC Pampalinda",cursoElectivo1)
estudiante1.matricularCursos("Lenguajes de Programacion")
estudiante1.matricularCursos("Big Data")
estudiante1.imprimirCursosMatriculados()

print(isinstance(estudiante1,Persona))
print(isinstance(estudiante1,Estudiante))
# Out:
# Digite el documento del primer estudiante: 10
# Digite el nombre del primer estudiante: 12
# Digite el telefono del primer estudiante: 12
# Cursos matriculados por 12:
#
# Curso electivo: Disin Thiking
# Otros cursos matriculados:
# Lenguajes de Programacion
# Big Data
# True
# True
